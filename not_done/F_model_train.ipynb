# %%
import sys
sys.path.append('..')

from scripts.global_funcs import load_data_config, load_model_config, get_num_of_classes
from glob import glob
import os



import nvtabular as nvt
import dask_cudf

from nvtabular.utils import device_mem_size

from dask_cuda import LocalCUDACluster
from dask.distributed import Client

import shutil

# import rmm
import pathlib
import numpy as np

# %%
model_config = load_model_config()
model_config
# Out:
# {'preblock_filters': 32,
#  'preblock_kernel_sizes': [7],
#  'preblock_pool_size': 3,
#  'idblock_kernel_sizes': [5],
#  'idblock_filters': [32, 64, 128],
#  'idblock_activation': 'gelu',
#  'idblock_avg_pool_sizes': [11],
#  'last_activation': 'softmax',
#  'batch_size': 4096,
#  'learn_rate': 0.0005,
#  'epochs': 300,
#  'patience': 299,
#  'num_warmup_epochs': 2,
#  'warmup_lr_multiplier': 0.001,
#  'from_logits': False,
#  'TF_MEMORY_ALLOCATION': '0.8',
#  'TF_VISIBLE_DEVICE': '0',
#  'TF_FORCE_GPU_ALLOW_GROWTH': 'true',
#  'device_spill_frac': 0.15,
#  'protocol': 'tcp',
#  'visible_devices': '0',
#  'enable_tcp_over_ucx': False,
#  'enable_nvlink': False,
#  'enable_infiniband': False,
#  'rmm_pool_size': '1GB',
#  'clear_models_dirs': True,
#  'clear_tensorboard': True}

# %%
preblock_filters = model_config['preblock_filters']
preblock_kernel_sizes = model_config['preblock_kernel_sizes']
preblock_pool_size = model_config['preblock_pool_size']
idblock_kernel_sizes = model_config['idblock_kernel_sizes']
idblock_filters = model_config['idblock_filters']
idblock_activation = model_config['idblock_activation']
idblock_avg_pool_sizes = model_config['idblock_avg_pool_sizes']
last_activation = model_config['last_activation']
batch_size = model_config['batch_size']
learn_rate = model_config['learn_rate']
epochs = model_config['epochs']
patience = model_config['patience']
clear_models_dirs = model_config['clear_models_dirs']
clear_tensorboard = model_config['clear_tensorboard']
num_warmup_epochs = model_config['num_warmup_epochs']
warmup_lr_multiplier = model_config['warmup_lr_multiplier']
from_logits = model_config['from_logits']

# %%
os.environ["TF_MEMORY_ALLOCATION"] = model_config['TF_MEMORY_ALLOCATION']  # fraction of free memory
os.environ["TF_VISIBLE_DEVICE"] = model_config['TF_VISIBLE_DEVICE'] 
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = model_config['TF_FORCE_GPU_ALLOW_GROWTH']

# %%
import tensorflow as tf
from scripts.cosme_model import COSMELayer
from nvtabular.loader.tensorflow import KerasSequenceLoader, KerasSequenceValidater
# Out:
# 2022-05-26 01:31:25.124006: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-26 01:31:25.124291: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-26 01:31:25.124402: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
config = load_data_config()
config
# Out:
# {'clean_fasta_file': '/media/jcosme/Data/MarRef_parquet_10_cats',
#  'output_dir': '/media/jcosme/Data',
#  'project_name': 'small_mer_1',
#  'base_col_names': ['seq', 'label'],
#  'label_col_name': 'label',
#  'input_col_name': 'seq',
#  'label_regex': '(?:[^a-zA-Z0-9]+)([a-zA-Z]+[0-9]+)(?:[^a-zA-Z0-9]+)',
#  'k_mer': 1,
#  'possible_gene_values': ['A', 'C', 'G', 'T'],
#  'max_seq_len': 150,
#  'data_splits': {'train': 0.9, 'val': 0.05, 'test': 0.05},
#  'random_seed': 42,
#  'fasta_sep': '>',
#  'unq_labs_dir': '/media/jcosme/Data/small_mer_1/data/unq_labels',
#  'unq_labs_dir_csv': '/media/jcosme/Data/small_mer_1/data/unq_labels.csv',
#  'data_dir': '/media/jcosme/Data/small_mer_1/data/small_mer_1',
#  'nvtab_dir': '/media/jcosme/Data/small_mer_1/nvtab',
#  'dask_dir': '/media/jcosme/Data/small_mer_1/dask',
#  'tensorboard_dir': '/media/jcosme/Data/small_mer_1/tensorboard',
#  'model_checkpoints_dir': '/media/jcosme/Data/small_mer_1/checkpoints/model_checkpoints',
#  'model_checkpoints_parent_dir': '/media/jcosme/Data/small_mer_1/checkpoints',
#  'model_weights_dir': '/media/jcosme/Data/small_mer_1/model_weights.h5'}

# %%
nvtab_dir = config['nvtab_dir']
label_col_name = config['label_col_name']
input_col_name = config['input_col_name']
dask_dir = config['dask_dir']
tensorboard_dir = config['tensorboard_dir']
model_checkpoints_dir = config['model_checkpoints_dir']
model_weights_dir = config['model_weights_dir']
max_seq_len = config['max_seq_len']
model_checkpoints_parent_dir = config['model_checkpoints_parent_dir']
possible_gene_values = config['possible_gene_values']
val_split = config['data_splits']['val']

# %%
if clear_models_dirs:
    try:
        shutil.rmtree(model_checkpoints_dir)
    except:
        pass
    try:
        shutil.rmtree(model_weights_dir)
    except:
        pass
    try:
        shutil.rmtree(model_checkpoints_parent_dir)
    except:
        pass
    
    
if clear_tensorboard: 
    try:
        shutil.rmtree(tensorboard_dir)
    except:
        pass

# %%
n_classes = get_num_of_classes()

# %%
# define some information about where to get our data
dask_workdir = pathlib.Path(nvtab_dir, "dask", "workdir")
stats_path = pathlib.Path(nvtab_dir, "dask", "stats")

# Make sure we have a clean worker space for Dask
if pathlib.Path.is_dir(dask_workdir):
    shutil.rmtree(dask_workdir)
dask_workdir.mkdir(parents=True)

# Make sure we have a clean stats space for Dask
if pathlib.Path.is_dir(stats_path):
    shutil.rmtree(stats_path)
stats_path.mkdir(parents=True)

cluster = LocalCUDACluster(
    protocol=model_config['protocol'],
    CUDA_VISIBLE_DEVICES=model_config['visible_devices'],
    device_memory_limit=device_mem_size(kind="total") * model_config['device_spill_frac'],
    enable_tcp_over_ucx=model_config['enable_tcp_over_ucx'],
    enable_nvlink=model_config['enable_nvlink'],
    enable_infiniband=model_config['enable_infiniband'],
    # rmm_pool_size=model_config['rmm_pool_size'],
    local_directory=dask_workdir,
)

client = Client(cluster)

# def _rmm_pool():
#     rmm.reinitialize(
#         pool_allocator=True,
#         initial_pool_size=None,  # Use default size
#     )
    
# client.run(_rmm_pool)
client
# Out:
# /home/jcosme/miniconda3/envs/COSME/lib/python3.7/site-packages/dask_cuda/initialize.py:45: UserWarning: A CUDA context for device 0 already exists on process ID 173497. This is often the result of a CUDA-enabled library calling a CUDA runtime function before Dask-CUDA can spawn worker processes. Please make sure any such function calls don't happen at import time or in the global scope of a program.
#   f"A CUDA context for device {ctx} already exists on process ID "
# distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# <Client: 'tcp://127.0.0.1:34321' processes=1 threads=1, memory=31.21 GiB>

# %%
TRAIN_PATHS = sorted(glob(f"{nvtab_dir}/train/*.parquet"))
VAL_PATHS = sorted(glob(f"{nvtab_dir}/val/*.parquet"))

# %%
# feed them to our datasets
train_dataset = KerasSequenceLoader(
    nvt.Dataset(TRAIN_PATHS, part_size="10MB"), # you could also use a glob pattern
    batch_size=batch_size,
    label_names=[label_col_name],
    cat_names=[input_col_name],
    shuffle=True,
    buffer_size=0.001,  # amount of data, as a fraction of GPU memory, to load at once,
    device=0,
    parts_per_chunk=1,
    engine="parquet",
)
# Out:
# /home/jcosme/miniconda3/envs/COSME/lib/python3.7/site-packages/nvtabular/io/parquet.py:291: UserWarning: Row group memory size (54058714) (bytes) of parquet file is bigger than requested part_size (10000000) for the NVTabular dataset.A row group memory size of 128 MB is generally recommended. You can find info on how to set the row group size of parquet files in https://nvidia-merlin.github.io/NVTabular/main/resources/troubleshooting.html#setting-the-row-group-size-for-the-parquet-files
#   f"Row group memory size ({rg_byte_size_0}) (bytes) of parquet file is bigger"

# %%
valid_dataset = KerasSequenceLoader(
    nvt.Dataset(VAL_PATHS, part_size="10MB"),   # you could also use a glob pattern
    batch_size=int(batch_size*val_split),
    label_names=[label_col_name],
    cat_names=[input_col_name],
    shuffle=False,
    buffer_size=0.001,  # amount of data, as a fraction of GPU memory, to load at once,
    device=0,
    parts_per_chunk=1,
    engine="parquet",
)

# %%
# batch = next(iter(train_dataset))

# %%
# tf.squeeze(batch[0]['seq'][1])

# %%
# dir(train_dataset)

# %%
@tf.function
def preprocess_data(inputs, targets):
    out = tf.RaggedTensor.from_row_lengths(tf.squeeze(inputs[input_col_name][0]),
                                                                  tf.squeeze(inputs[input_col_name][1]),
                                                                 ).to_tensor(max_seq_len)
    # out = tf.cast(out, tf.float32)
    out = tf.expand_dims(out, 1)
    out = tf.expand_dims(out, -1)
    
    # return out, targets
    
    tars = tf.one_hot(targets, n_classes) 
    tars = tf.cast(tars, tf.float32)
    tars = tf.squeeze(tars, axis=1)
    
    return out, tars

# %%
# inputs = batch[0]
# targets = batch[1]

# %%
# tf.squeeze(inputs[input_col_name][0])

# %%
# make_batches(*batch)

# %%
train_dataset = train_dataset.map(preprocess_data)
valid_dataset = valid_dataset.map(preprocess_data)

# %%
# batch = next(iter(train_dataset))

# %%
# train_dataset_reshaped = tf.RaggedTensor.from_row_lengths(train_dataset[0][input_col_name][0], train_dataset[0][input_col_name][1]).to_tensor(max_seq_len)

# %%
inputs = tf.keras.Input(name=f"{input_col_name}", dtype=tf.float32, shape=(1, max_seq_len, 1,))

inputs = tf.cast(inputs, tf.float32)

inputs = tf.math.multiply(inputs, 1/len(possible_gene_values))
# Out:
# 2022-05-26 01:31:28.458927: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-26 01:31:28.459483: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-26 01:31:28.459663: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-26 01:31:28.459796: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-26 01:31:28.460011: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-26 01:31:28.460130: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-26 01:31:28.460240: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-26 01:31:28.460310: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-05-26 01:31:28.460328: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13107 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# first_filter_size = 64
# block_reps = [3, 4, 6, 3]
# activation = 'relu'
# gen_filter_size = 12
# bn_momen = 0.5

# outputs = tf.keras.layers.Conv2D(first_filter_size, (1, 7), padding='same', strides=1)(inputs)
# outputs = tf.keras.layers.BatchNormalization(momentum=bn_momen)(outputs)
# outputs = tf.keras.layers.Activation(activation)(outputs)
# outputs = tf.keras.layers.MaxPool2D(pool_size=(1,3), padding='same', strides=1)(outputs)

# cur_filter_size = first_filter_size
# for br_i, block_rep in enumerate(block_reps):
#     # print(block_rep)
#     for r_i in np.arange(block_rep):
#         # print(f"\t{r_i}")
        
#         if r_i == 0:
#             # print(f"\t\t{cur_filter_size * 4}")
#             skip_layer = outputs
#             skip_layer = tf.keras.layers.Conv2D(cur_filter_size*4, (1, 1), padding='same', strides=1)(skip_layer)
#             skip_layer = tf.keras.layers.BatchNormalization(momentum=bn_momen)(skip_layer)
#         else:
#             skip_layer = outputs
        
#         outputs = tf.keras.layers.Conv2D(cur_filter_size, (1, 1), padding='same', strides=1)(outputs)
#         outputs = tf.keras.layers.BatchNormalization(momentum=bn_momen)(outputs)
#         outputs = tf.keras.layers.Activation(activation)(outputs)
        
#         outputs = tf.keras.layers.Conv2D(cur_filter_size, (1, gen_filter_size), padding='same', strides=1)(outputs)
#         outputs = tf.keras.layers.BatchNormalization(momentum=bn_momen)(outputs)
        
#         outputs = tf.keras.layers.Conv2D(cur_filter_size * 4, (1, 1), padding='same', strides=1)(outputs)
#         outputs = tf.keras.layers.BatchNormalization(momentum=bn_momen)(outputs)
        
#         outputs = tf.keras.layers.Add()([outputs, skip_layer])
#         outputs = tf.keras.layers.Activation(activation)(outputs)
        
#     cur_filter_size *= 2

# outputs = tf.keras.layers.GlobalAveragePooling2D()(outputs)
# outputs = tf.keras.layers.Dense(n_classes)(outputs)
# outputs = tf.keras.layers.Activation('sigmoid')(outputs)

# %%
# cosme_model = tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
# cosme_model(batch[0])

# %%
resblock_filters = [16, 32, 64]
bn_momen = 0.1
activation = 'relu'

preblock_a = tf.keras.layers.Conv1D(16, 3, padding='same', strides=1)(inputs)
preblock_a = tf.keras.layers.BatchNormalization(momentum=bn_momen)(preblock_a)
preblock_a = tf.keras.layers.Activation(activation)(preblock_a)
# preblock_a = tf.keras.layers.BatchNormalization(momentum=bn_momen)(preblock_a)
preblock_a = tf.keras.layers.MaxPool2D(pool_size=(1,3), padding='same', strides=1)(preblock_a)


resblock_a_kernel = 3
resblock_a_1_skip = tf.keras.layers.Conv1D(resblock_filters[0], 1, padding='same', strides=1)(preblock_a)
resblock_a_1 = tf.keras.layers.Conv1D(resblock_filters[0], resblock_a_kernel, padding='same', strides=1)(resblock_a_1_skip)
resblock_a_1 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_a_1)
resblock_a_1 = tf.keras.layers.Activation(activation)(resblock_a_1)
# resblock_a_1 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_a_1)
resblock_a_1 = tf.keras.layers.Conv1D(resblock_filters[0], resblock_a_kernel, padding='same', strides=1)(resblock_a_1)
resblock_a_1 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_a_1)
resblock_a_1 = tf.keras.layers.Add()([resblock_a_1, resblock_a_1_skip])
resblock_a_1 = tf.keras.layers.Activation(activation)(resblock_a_1)
# resblock_a_1 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_a_1)

resblock_a_2_skip = tf.keras.layers.Conv1D(resblock_filters[1], 1, padding='same', strides=1)(resblock_a_1)
resblock_a_2 = tf.keras.layers.Conv1D(resblock_filters[1], resblock_a_kernel, padding='same', strides=1)(resblock_a_2_skip)
resblock_a_2 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_a_2)
resblock_a_2 = tf.keras.layers.Activation(activation)(resblock_a_2)
# resblock_a_2 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_a_2)
resblock_a_2 = tf.keras.layers.Conv1D(resblock_filters[1], resblock_a_kernel, padding='same', strides=1)(resblock_a_2)
resblock_a_2 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_a_2)
resblock_a_2 = tf.keras.layers.Add()([resblock_a_2, resblock_a_2_skip])
resblock_a_2 = tf.keras.layers.Activation(activation)(resblock_a_2)
# resblock_a_2 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_a_1)

resblock_a_3_skip = tf.keras.layers.Conv1D(resblock_filters[2], 1, padding='same', strides=1)(resblock_a_2)
resblock_a_3 = tf.keras.layers.Conv1D(resblock_filters[2], resblock_a_kernel, padding='same', strides=1)(resblock_a_3_skip)
resblock_a_3 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_a_3)
resblock_a_3 = tf.keras.layers.Activation(activation)(resblock_a_3)
# resblock_a_3 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_a_3)
resblock_a_3 = tf.keras.layers.Conv1D(resblock_filters[2], resblock_a_kernel, padding='same', strides=1)(resblock_a_3)
resblock_a_3 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_a_3)
resblock_a_3 = tf.keras.layers.Add()([resblock_a_3, resblock_a_3_skip])
resblock_a_3 = tf.keras.layers.Activation(activation)(resblock_a_3)
# resblock_a_3 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_a_3)

# resblock_a_3 = tf.keras.layers.AveragePooling2D(pool_size=(1, 2), strides=1, padding='valid')(resblock_a_3)

resblock_b_kernel = 5
resblock_b_1_skip = tf.keras.layers.Conv1D(resblock_filters[0], 1, padding='same', strides=1)(preblock_a)
resblock_b_1 = tf.keras.layers.Conv1D(resblock_filters[0], resblock_b_kernel, padding='same', strides=1)(resblock_b_1_skip)
resblock_b_1 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_b_1)
resblock_b_1 = tf.keras.layers.Activation(activation)(resblock_b_1)
# resblock_b_1 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_b_1)
resblock_b_1 = tf.keras.layers.Conv1D(resblock_filters[0], resblock_b_kernel, padding='same', strides=1)(resblock_b_1)
resblock_b_1 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_b_1)
resblock_b_1 = tf.keras.layers.Add()([resblock_b_1, resblock_b_1_skip])
resblock_b_1 = tf.keras.layers.Activation(activation)(resblock_b_1)
# resblock_b_1 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_b_1)

resblock_b_2_skip = tf.keras.layers.Conv1D(resblock_filters[1], 1, padding='same', strides=1)(resblock_b_1)
resblock_b_2 = tf.keras.layers.Conv1D(resblock_filters[1], resblock_b_kernel, padding='same', strides=1)(resblock_b_2_skip)
resblock_b_2 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_b_2)
resblock_b_2 = tf.keras.layers.Activation(activation)(resblock_b_2)
# resblock_b_2 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_b_2)
resblock_b_2 = tf.keras.layers.Conv1D(resblock_filters[1], resblock_b_kernel, padding='same', strides=1)(resblock_b_2)
resblock_b_2 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_b_2)
resblock_b_2 = tf.keras.layers.Add()([resblock_b_2, resblock_b_2_skip])
resblock_b_2 = tf.keras.layers.Activation(activation)(resblock_b_2)
# resblock_b_2 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_b_1)

resblock_b_3_skip = tf.keras.layers.Conv1D(resblock_filters[2], 1, padding='same', strides=1)(resblock_b_2)
resblock_b_3 = tf.keras.layers.Conv1D(resblock_filters[2], resblock_b_kernel, padding='same', strides=1)(resblock_b_3_skip)
resblock_b_3 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_b_3)
resblock_b_3 = tf.keras.layers.Activation(activation)(resblock_b_3)
# resblock_b_3 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_b_3)
resblock_b_3 = tf.keras.layers.Conv1D(resblock_filters[2], resblock_b_kernel, padding='same', strides=1)(resblock_b_3)
resblock_b_3 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_b_3)
resblock_b_3 = tf.keras.layers.Add()([resblock_b_3, resblock_b_3_skip])
resblock_b_3 = tf.keras.layers.Activation(activation)(resblock_b_3)
# resblock_b_3 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_b_3)

# resblock_b_3 = tf.keras.layers.AveragePooling2D(pool_size=(1, 2), strides=1, padding='valid')(resblock_b_3)

resblock_c_kernel = 7
resblock_c_1_skip = tf.keras.layers.Conv1D(resblock_filters[0], 1, padding='same', strides=1)(preblock_a)
resblock_c_1 = tf.keras.layers.Conv1D(resblock_filters[0], resblock_c_kernel, padding='same', strides=1)(resblock_c_1_skip)
resblock_c_1 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_c_1)
resblock_c_1 = tf.keras.layers.Activation(activation)(resblock_c_1)
# resblock_c_1 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_c_1)
resblock_c_1 = tf.keras.layers.Conv1D(resblock_filters[0], resblock_c_kernel, padding='same', strides=1)(resblock_c_1)
resblock_c_1 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_c_1)
resblock_c_1 = tf.keras.layers.Add()([resblock_c_1, resblock_c_1_skip])
resblock_c_1 = tf.keras.layers.Activation(activation)(resblock_c_1)
# resblock_c_1 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_c_1)

resblock_c_2_skip = tf.keras.layers.Conv1D(resblock_filters[1], 1, padding='same', strides=1)(resblock_c_1)
resblock_c_2 = tf.keras.layers.Conv1D(resblock_filters[1], resblock_c_kernel, padding='same', strides=1)(resblock_c_2_skip)
resblock_c_2 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_c_2)
resblock_c_2 = tf.keras.layers.Activation(activation)(resblock_c_2)
# resblock_c_2 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_c_2)
resblock_c_2 = tf.keras.layers.Conv1D(resblock_filters[1], resblock_c_kernel, padding='same', strides=1)(resblock_c_2)
resblock_c_2 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_c_2)
resblock_c_2 = tf.keras.layers.Add()([resblock_c_2, resblock_c_2_skip])
resblock_c_2 = tf.keras.layers.Activation(activation)(resblock_c_2)
# resblock_c_2 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_c_2)

resblock_c_3_skip = tf.keras.layers.Conv1D(resblock_filters[2], 1, padding='same', strides=1)(resblock_c_2)
resblock_c_3 = tf.keras.layers.Conv1D(resblock_filters[2], resblock_c_kernel, padding='same', strides=1)(resblock_c_3_skip)
resblock_c_3 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_c_3)
resblock_c_3 = tf.keras.layers.Activation(activation)(resblock_c_3)
# resblock_c_3 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_c_3)
resblock_c_3 = tf.keras.layers.Conv1D(resblock_filters[2], resblock_c_kernel, padding='same', strides=1)(resblock_c_3)
resblock_c_3 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_c_3)
resblock_c_3 = tf.keras.layers.Add()([resblock_c_3, resblock_c_3_skip])
resblock_c_3 = tf.keras.layers.Activation(activation)(resblock_c_3)
# resblock_c_3 = tf.keras.layers.BatchNormalization(momentum=bn_momen)(resblock_c_3)

# resblock_c_3 = tf.keras.layers.AveragePooling2D(pool_size=(1, 2), strides=1, padding='valid')(resblock_c_3)

                                                       
# resblock_d_kernel = 9
# resblock_d_1 = tf.keras.layers.Conv1D(resblock_filters[0], resblock_d_kernel, padding='same', strides=1)(preblock_a)
# # resblock_d_1 = tf.keras.layers.BatchNormalization()(resblock_d_1)
# resblock_d_1 = tf.keras.layers.Activation('gelu')(resblock_d_1)
# resblock_d_1 = tf.keras.layers.BatchNormalization()(resblock_d_1)
# resblock_d_1 = tf.keras.layers.Conv1D(resblock_filters[0], resblock_d_kernel, padding='same', strides=1)(resblock_d_1)
# # resblock_d_1 = tf.keras.layers.BatchNormalization()(resblock_d_1)
# resblock_d_1 = tf.keras.layers.Concatenate()([resblock_d_1, preblock_a])
# resblock_d_1 = tf.keras.layers.Activation('gelu')(resblock_d_1)
# resblock_d_1 = tf.keras.layers.BatchNormalization()(resblock_d_1)

# resblock_d_2 = tf.keras.layers.Conv1D(resblock_filters[1], resblock_d_kernel, padding='same', strides=1)(resblock_d_1)
# # resblock_d_2 = tf.keras.layers.BatchNormalization()(resblock_d_2)
# resblock_d_2 = tf.keras.layers.Activation('gelu')(resblock_d_2)
# resblock_d_2 = tf.keras.layers.BatchNormalization()(resblock_d_2)
# resblock_d_2 = tf.keras.layers.Conv1D(resblock_filters[1], resblock_d_kernel, padding='same', strides=1)(resblock_d_2)
# # resblock_d_2 = tf.keras.layers.BatchNormalization()(resblock_d_2)
# resblock_d_2 = tf.keras.layers.Concatenate()([resblock_d_2, resblock_d_1])
# resblock_d_2 = tf.keras.layers.Activation('gelu')(resblock_d_2)
# resblock_d_2 = tf.keras.layers.BatchNormalization()(resblock_d_1)

# resblock_d_3 = tf.keras.layers.Conv1D(resblock_filters[2], resblock_d_kernel, padding='same', strides=1)(resblock_d_2)
# # resblock_d_3 = tf.keras.layers.BatchNormalization()(resblock_d_3)
# resblock_d_3 = tf.keras.layers.Activation('gelu')(resblock_d_3)
# resblock_d_3 = tf.keras.layers.BatchNormalization()(resblock_d_3)
# resblock_d_3 = tf.keras.layers.Conv1D(resblock_filters[2], resblock_d_kernel, padding='same', strides=1)(resblock_d_3)
# # resblock_d_3 = tf.keras.layers.BatchNormalization()(resblock_d_3)
# resblock_d_3 = tf.keras.layers.Concatenate()([resblock_d_3, resblock_d_2])
# resblock_d_3 = tf.keras.layers.Activation('gelu')(resblock_d_3)
# resblock_d_3 = tf.keras.layers.BatchNormalization()(resblock_d_3)

# resblock_d_3 = tf.keras.layers.AveragePooling2D(pool_size=(1, 2), strides=1, padding='valid')(resblock_d_3)


outputs = tf.keras.layers.Concatenate()([resblock_a_3, resblock_b_3, resblock_c_3])#, resblock_d_3])
outputs = tf.keras.layers.GlobalAveragePooling2D()(outputs)
# outputs = tf.keras.layers.Flatten()(outputs)
outputs = tf.keras.layers.Dense(n_classes, activation='sigmoid')(outputs)

# %%
cosme_model = tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
# # preproc = tf.keras.layers.Lambda(lambda x: tf.RaggedTensor.from_row_lengths(x[input_col_name][0], x[input_col_name][1]).to_tensor(max_seq_len))(inputs)
# preproc = tf.RaggedTensor.from_row_lengths(inputs[input_col_name][0], inputs[input_col_name][1]).to_tensor(max_seq_len)
# preproc = tf.reshape(preproc, [max_seq_len,])
# preproc = tf.expand_dims(preproc, 1)
# preproc = tf.expand_dims(preproc, 3)
# preproc = tf.math.multiply(preproc, 1/len(possible_gene_values))

# %%
# cosme_model = tf.keras.Model(inputs=inputs, outputs=preproc)

# %%
# cosme_model(batch[0])

# %%
# preproc = tf.keras.layers.Lambda(lambda x: x['seq'][0])(inputs)
# throw_way = tf.keras.layers.Lambda(lambda x: x['seq'][1])(inputs)
# shape = [tf.shape(throw_way)[k] for k in range(2)]
# preproc = tf.reshape(preproc, [shape[0], max_seq_len])
# preproc = tf.cast(preproc, tf.float32)
# preproc = tf.expand_dims(preproc, 0)
# preproc = tf.reshape(preproc, [shape[0], 1, max_seq_len])
# preproc = tf.math.multiply(preproc, 1/len(possible_gene_values))

# %%
# cosme_layer = COSMELayer(
#                 preblock_filters=preblock_filters,
#                 preblock_kernel_sizes=preblock_kernel_sizes,
#                 preblock_pool_size=preblock_pool_size,
#                 idblock_kernel_sizes=idblock_kernel_sizes,
#                 idblock_filters = idblock_filters,
#                 idblock_activation=idblock_activation,
#                 idblock_avg_pool_sizes=idblock_avg_pool_sizes,
#                 last_activation=last_activation,
#                 n_classes=n_classes,
#                 )
# output_layer = cosme_layer(inputs)

# %%
# cosme_model = tf.keras.Model(inputs=inputs, outputs=output_layer)

# %%
# cosme_model.layers[-1]._name = 'COSMELayer'

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=learn_rate, amsgrad=True)

# %%
# step = tf.Variable(0, trainable=False)
# schedule = tf.optimizers.schedules.PiecewiseConstantDecay(
#     [10000, 15000], [1e-0, 1e-1, 1e-2])
# # lr and wd can be a function or a tensor
# lr = 1e-1 * schedule(step)
# wd = lambda: 1e-4 * schedule(step)


# optimizer = tf.optimizers.AdamW(learning_rate=lr, weight_decay=wd)
# optimizer = tf.keras.optimizers.experimental.AdamW()

# %%
cosme_model.compile(optimizer, 
              # loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=from_logits),#, reduction=tf.keras.losses.Reduction.NONE), 
                    # loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),#, reduction=tf.keras.losses.Reduction.NONE), 
                    loss=tf.keras.losses.BinaryFocalCrossentropy(),
              # metrics=['sparse_categorical_accuracy'],
                    metrics=['categorical_accuracy'],
             )

# %%
validation_callback = KerasSequenceValidater(valid_dataset)

# %%
earlystopping_cb = tf.keras.callbacks.EarlyStopping(
                        monitor='val_loss',
                        patience=patience,
                        restore_best_weights=True
                    )

checkpoints_cb = tf.keras.callbacks.ModelCheckpoint(
    filepath=model_checkpoints_dir,
    save_weights_only=True,
    monitor='val_accuracy',
   )

tensorboard_cb = tf.keras.callbacks.TensorBoard(
    log_dir=tensorboard_dir,
    histogram_freq=1,
)

restore_cb = tf.keras.callbacks.BackupAndRestore(backup_dir=model_checkpoints_dir)

def lr_scheduler(epoch, lr):
    if epoch < num_warmup_epochs:
        return learn_rate * warmup_lr_multiplier
    else:
        return learn_rate #* (0.9**int(epoch / 100))
    
scheduler_cb = tf.keras.callbacks.LearningRateScheduler(lr_scheduler)

# %%
# cosme_model.summary()

# %%
history = cosme_model.fit(
    train_dataset,
    epochs=epochs,
    validation_data=valid_dataset,
    callbacks=[ earlystopping_cb, checkpoints_cb, tensorboard_cb, restore_cb, scheduler_cb]
)
# Out:
# Epoch 1/300
# 2022-05-26 01:31:34.967485: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8201
# 2022-05-26 01:31:35.641513: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-05-26 01:31:36.500614: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 36/36 [==============================] - 23s 389ms/step - loss: 0.2647 - categorical_accuracy: 0.0640 - val_loss: 0.2625 - val_categorical_accuracy: 0.0654 - lr: 5.0000e-07
# Epoch 2/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.2625 - categorical_accuracy: 0.0640 - val_loss: 0.2603 - val_categorical_accuracy: 0.0655 - lr: 5.0000e-07
# Epoch 3/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.1014 - categorical_accuracy: 0.2097 - val_loss: 0.0951 - val_categorical_accuracy: 0.2897 - lr: 5.0000e-04
# Epoch 4/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.1070 - categorical_accuracy: 0.1025 - val_loss: 0.0821 - val_categorical_accuracy: 0.3025 - lr: 5.0000e-04
# Epoch 5/300
# 36/36 [==============================] - 13s 347ms/step - loss: 0.0953 - categorical_accuracy: 0.0806 - val_loss: 0.0804 - val_categorical_accuracy: 0.3068 - lr: 5.0000e-04
# Epoch 6/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0952 - categorical_accuracy: 0.0635 - val_loss: 0.0770 - val_categorical_accuracy: 0.3129 - lr: 5.0000e-04
# Epoch 7/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0887 - categorical_accuracy: 0.0819 - val_loss: 0.0758 - val_categorical_accuracy: 0.3283 - lr: 5.0000e-04
# Epoch 8/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0877 - categorical_accuracy: 0.0966 - val_loss: 0.0754 - val_categorical_accuracy: 0.3389 - lr: 5.0000e-04
# Epoch 9/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0841 - categorical_accuracy: 0.1204 - val_loss: 0.0752 - val_categorical_accuracy: 0.3419 - lr: 5.0000e-04
# Epoch 10/300
# 36/36 [==============================] - 13s 350ms/step - loss: 0.0857 - categorical_accuracy: 0.0959 - val_loss: 0.0727 - val_categorical_accuracy: 0.3703 - lr: 5.0000e-04
# Epoch 11/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0826 - categorical_accuracy: 0.1291 - val_loss: 0.0726 - val_categorical_accuracy: 0.3585 - lr: 5.0000e-04
# Epoch 12/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0823 - categorical_accuracy: 0.1300 - val_loss: 0.0743 - val_categorical_accuracy: 0.3548 - lr: 5.0000e-04
# Epoch 13/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0834 - categorical_accuracy: 0.1426 - val_loss: 0.0716 - val_categorical_accuracy: 0.3612 - lr: 5.0000e-04
# Epoch 14/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0812 - categorical_accuracy: 0.1852 - val_loss: 0.0745 - val_categorical_accuracy: 0.3572 - lr: 5.0000e-04
# Epoch 15/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0834 - categorical_accuracy: 0.1474 - val_loss: 0.0719 - val_categorical_accuracy: 0.3759 - lr: 5.0000e-04
# Epoch 16/300
# 36/36 [==============================] - 13s 350ms/step - loss: 0.0800 - categorical_accuracy: 0.1667 - val_loss: 0.0769 - val_categorical_accuracy: 0.3583 - lr: 5.0000e-04
# Epoch 17/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0800 - categorical_accuracy: 0.1760 - val_loss: 0.0754 - val_categorical_accuracy: 0.3694 - lr: 5.0000e-04
# Epoch 18/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0793 - categorical_accuracy: 0.1727 - val_loss: 0.0719 - val_categorical_accuracy: 0.3952 - lr: 5.0000e-04
# Epoch 19/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0783 - categorical_accuracy: 0.1667 - val_loss: 0.0733 - val_categorical_accuracy: 0.3697 - lr: 5.0000e-04
# Epoch 20/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0788 - categorical_accuracy: 0.1766 - val_loss: 0.0704 - val_categorical_accuracy: 0.3788 - lr: 5.0000e-04
# Epoch 21/300
# 36/36 [==============================] - 13s 350ms/step - loss: 0.0757 - categorical_accuracy: 0.1819 - val_loss: 0.0718 - val_categorical_accuracy: 0.3898 - lr: 5.0000e-04
# Epoch 22/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0748 - categorical_accuracy: 0.2016 - val_loss: 0.0713 - val_categorical_accuracy: 0.3887 - lr: 5.0000e-04
# Epoch 23/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0743 - categorical_accuracy: 0.2311 - val_loss: 0.0719 - val_categorical_accuracy: 0.3966 - lr: 5.0000e-04
# Epoch 24/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0736 - categorical_accuracy: 0.2302 - val_loss: 0.0719 - val_categorical_accuracy: 0.3915 - lr: 5.0000e-04
# Epoch 25/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0732 - categorical_accuracy: 0.2436 - val_loss: 0.0702 - val_categorical_accuracy: 0.4006 - lr: 5.0000e-04
# Epoch 26/300
# 36/36 [==============================] - 13s 352ms/step - loss: 0.0718 - categorical_accuracy: 0.2487 - val_loss: 0.0702 - val_categorical_accuracy: 0.3947 - lr: 5.0000e-04
# Epoch 27/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0727 - categorical_accuracy: 0.2335 - val_loss: 0.0700 - val_categorical_accuracy: 0.3953 - lr: 5.0000e-04
# Epoch 28/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0712 - categorical_accuracy: 0.2657 - val_loss: 0.0700 - val_categorical_accuracy: 0.3975 - lr: 5.0000e-04
# Epoch 29/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.0708 - categorical_accuracy: 0.2814 - val_loss: 0.0713 - val_categorical_accuracy: 0.4084 - lr: 5.0000e-04
# Epoch 30/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0702 - categorical_accuracy: 0.2797 - val_loss: 0.0713 - val_categorical_accuracy: 0.4016 - lr: 5.0000e-04
# Epoch 31/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0697 - categorical_accuracy: 0.2933 - val_loss: 0.0710 - val_categorical_accuracy: 0.4077 - lr: 5.0000e-04
# Epoch 32/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0690 - categorical_accuracy: 0.3042 - val_loss: 0.0706 - val_categorical_accuracy: 0.4098 - lr: 5.0000e-04
# Epoch 33/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0683 - categorical_accuracy: 0.3030 - val_loss: 0.0702 - val_categorical_accuracy: 0.3977 - lr: 5.0000e-04
# Epoch 34/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0680 - categorical_accuracy: 0.3188 - val_loss: 0.0706 - val_categorical_accuracy: 0.3951 - lr: 5.0000e-04
# Epoch 35/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0676 - categorical_accuracy: 0.3098 - val_loss: 0.0701 - val_categorical_accuracy: 0.4006 - lr: 5.0000e-04
# Epoch 36/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0671 - categorical_accuracy: 0.3319 - val_loss: 0.0696 - val_categorical_accuracy: 0.4041 - lr: 5.0000e-04
# Epoch 37/300
# 36/36 [==============================] - 13s 350ms/step - loss: 0.0667 - categorical_accuracy: 0.3281 - val_loss: 0.0699 - val_categorical_accuracy: 0.3995 - lr: 5.0000e-04
# Epoch 38/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0674 - categorical_accuracy: 0.3265 - val_loss: 0.0730 - val_categorical_accuracy: 0.3773 - lr: 5.0000e-04
# Epoch 39/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0677 - categorical_accuracy: 0.3242 - val_loss: 0.0710 - val_categorical_accuracy: 0.4055 - lr: 5.0000e-04
# Epoch 40/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0676 - categorical_accuracy: 0.3270 - val_loss: 0.0707 - val_categorical_accuracy: 0.4112 - lr: 5.0000e-04
# Epoch 41/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0658 - categorical_accuracy: 0.3440 - val_loss: 0.0712 - val_categorical_accuracy: 0.4072 - lr: 5.0000e-04
# Epoch 42/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0653 - categorical_accuracy: 0.3497 - val_loss: 0.0702 - val_categorical_accuracy: 0.3913 - lr: 5.0000e-04
# Epoch 43/300
# 36/36 [==============================] - 13s 350ms/step - loss: 0.0648 - categorical_accuracy: 0.3523 - val_loss: 0.0701 - val_categorical_accuracy: 0.3932 - lr: 5.0000e-04
# Epoch 44/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0642 - categorical_accuracy: 0.3631 - val_loss: 0.0710 - val_categorical_accuracy: 0.3862 - lr: 5.0000e-04
# Epoch 45/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0637 - categorical_accuracy: 0.3688 - val_loss: 0.0717 - val_categorical_accuracy: 0.3821 - lr: 5.0000e-04
# Epoch 46/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0632 - categorical_accuracy: 0.3681 - val_loss: 0.0710 - val_categorical_accuracy: 0.3757 - lr: 5.0000e-04
# Epoch 47/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0627 - categorical_accuracy: 0.3860 - val_loss: 0.0716 - val_categorical_accuracy: 0.3687 - lr: 5.0000e-04
# Epoch 48/300
# 36/36 [==============================] - 13s 352ms/step - loss: 0.0626 - categorical_accuracy: 0.3992 - val_loss: 0.0734 - val_categorical_accuracy: 0.3752 - lr: 5.0000e-04
# Epoch 49/300
# 36/36 [==============================] - 13s 346ms/step - loss: 0.0627 - categorical_accuracy: 0.4019 - val_loss: 0.0759 - val_categorical_accuracy: 0.3463 - lr: 5.0000e-04
# Epoch 50/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0635 - categorical_accuracy: 0.3763 - val_loss: 0.0770 - val_categorical_accuracy: 0.3603 - lr: 5.0000e-04
# Epoch 51/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0623 - categorical_accuracy: 0.3877 - val_loss: 0.0812 - val_categorical_accuracy: 0.3443 - lr: 5.0000e-04
# Epoch 52/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0652 - categorical_accuracy: 0.3644 - val_loss: 0.0795 - val_categorical_accuracy: 0.3428 - lr: 5.0000e-04
# Epoch 53/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0641 - categorical_accuracy: 0.3680 - val_loss: 0.0784 - val_categorical_accuracy: 0.3555 - lr: 5.0000e-04
# Epoch 54/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0629 - categorical_accuracy: 0.3647 - val_loss: 0.0784 - val_categorical_accuracy: 0.3732 - lr: 5.0000e-04
# Epoch 55/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0608 - categorical_accuracy: 0.3918 - val_loss: 0.0799 - val_categorical_accuracy: 0.3735 - lr: 5.0000e-04
# Epoch 56/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0601 - categorical_accuracy: 0.3917 - val_loss: 0.0780 - val_categorical_accuracy: 0.3740 - lr: 5.0000e-04
# Epoch 57/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0608 - categorical_accuracy: 0.3920 - val_loss: 0.0768 - val_categorical_accuracy: 0.3831 - lr: 5.0000e-04
# Epoch 58/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0593 - categorical_accuracy: 0.4307 - val_loss: 0.0777 - val_categorical_accuracy: 0.3829 - lr: 5.0000e-04
# Epoch 59/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0583 - categorical_accuracy: 0.4222 - val_loss: 0.0782 - val_categorical_accuracy: 0.3833 - lr: 5.0000e-04
# Epoch 60/300
# 36/36 [==============================] - 13s 352ms/step - loss: 0.0582 - categorical_accuracy: 0.4432 - val_loss: 0.0794 - val_categorical_accuracy: 0.3817 - lr: 5.0000e-04
# Epoch 61/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0576 - categorical_accuracy: 0.4421 - val_loss: 0.0830 - val_categorical_accuracy: 0.3751 - lr: 5.0000e-04
# Epoch 62/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0588 - categorical_accuracy: 0.4172 - val_loss: 0.0793 - val_categorical_accuracy: 0.3838 - lr: 5.0000e-04
# Epoch 63/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0577 - categorical_accuracy: 0.4377 - val_loss: 0.0797 - val_categorical_accuracy: 0.3809 - lr: 5.0000e-04
# Epoch 64/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0574 - categorical_accuracy: 0.4304 - val_loss: 0.0817 - val_categorical_accuracy: 0.3865 - lr: 5.0000e-04
# Epoch 65/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0577 - categorical_accuracy: 0.4276 - val_loss: 0.0815 - val_categorical_accuracy: 0.3836 - lr: 5.0000e-04
# Epoch 66/300
# 36/36 [==============================] - 13s 341ms/step - loss: 0.0574 - categorical_accuracy: 0.4313 - val_loss: 0.0748 - val_categorical_accuracy: 0.3694 - lr: 5.0000e-04
# Epoch 67/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0593 - categorical_accuracy: 0.4076 - val_loss: 0.0747 - val_categorical_accuracy: 0.3791 - lr: 5.0000e-04
# Epoch 68/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0585 - categorical_accuracy: 0.4237 - val_loss: 0.0749 - val_categorical_accuracy: 0.3781 - lr: 5.0000e-04
# Epoch 69/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0575 - categorical_accuracy: 0.4353 - val_loss: 0.0771 - val_categorical_accuracy: 0.3822 - lr: 5.0000e-04
# Epoch 70/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0571 - categorical_accuracy: 0.4301 - val_loss: 0.0742 - val_categorical_accuracy: 0.3847 - lr: 5.0000e-04
# Epoch 71/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0566 - categorical_accuracy: 0.4461 - val_loss: 0.0708 - val_categorical_accuracy: 0.4020 - lr: 5.0000e-04
# Epoch 72/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0564 - categorical_accuracy: 0.4594 - val_loss: 0.0720 - val_categorical_accuracy: 0.4010 - lr: 5.0000e-04
# Epoch 73/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0560 - categorical_accuracy: 0.4565 - val_loss: 0.0751 - val_categorical_accuracy: 0.3863 - lr: 5.0000e-04
# Epoch 74/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0552 - categorical_accuracy: 0.4733 - val_loss: 0.0746 - val_categorical_accuracy: 0.3964 - lr: 5.0000e-04
# Epoch 75/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0546 - categorical_accuracy: 0.4947 - val_loss: 0.0761 - val_categorical_accuracy: 0.3919 - lr: 5.0000e-04
# Epoch 76/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0549 - categorical_accuracy: 0.4881 - val_loss: 0.0775 - val_categorical_accuracy: 0.3932 - lr: 5.0000e-04
# Epoch 77/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0543 - categorical_accuracy: 0.5032 - val_loss: 0.0768 - val_categorical_accuracy: 0.3896 - lr: 5.0000e-04
# Epoch 78/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0539 - categorical_accuracy: 0.5030 - val_loss: 0.0800 - val_categorical_accuracy: 0.3799 - lr: 5.0000e-04
# Epoch 79/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0541 - categorical_accuracy: 0.5077 - val_loss: 0.0791 - val_categorical_accuracy: 0.3863 - lr: 5.0000e-04
# Epoch 80/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0546 - categorical_accuracy: 0.5058 - val_loss: 0.0790 - val_categorical_accuracy: 0.3793 - lr: 5.0000e-04
# Epoch 81/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0544 - categorical_accuracy: 0.5074 - val_loss: 0.0772 - val_categorical_accuracy: 0.3784 - lr: 5.0000e-04
# Epoch 82/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0541 - categorical_accuracy: 0.5164 - val_loss: 0.0759 - val_categorical_accuracy: 0.3766 - lr: 5.0000e-04
# Epoch 83/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0544 - categorical_accuracy: 0.5203 - val_loss: 0.0769 - val_categorical_accuracy: 0.3788 - lr: 5.0000e-04
# Epoch 84/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0531 - categorical_accuracy: 0.5448 - val_loss: 0.0814 - val_categorical_accuracy: 0.3766 - lr: 5.0000e-04
# Epoch 85/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0536 - categorical_accuracy: 0.5348 - val_loss: 0.0831 - val_categorical_accuracy: 0.3716 - lr: 5.0000e-04
# Epoch 86/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0539 - categorical_accuracy: 0.5293 - val_loss: 0.0856 - val_categorical_accuracy: 0.3659 - lr: 5.0000e-04
# Epoch 87/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0560 - categorical_accuracy: 0.4736 - val_loss: 0.0889 - val_categorical_accuracy: 0.3715 - lr: 5.0000e-04
# Epoch 88/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0581 - categorical_accuracy: 0.4340 - val_loss: 0.0782 - val_categorical_accuracy: 0.3899 - lr: 5.0000e-04
# Epoch 89/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0561 - categorical_accuracy: 0.4689 - val_loss: 0.0737 - val_categorical_accuracy: 0.3918 - lr: 5.0000e-04
# Epoch 90/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0562 - categorical_accuracy: 0.4524 - val_loss: 0.0744 - val_categorical_accuracy: 0.3861 - lr: 5.0000e-04
# Epoch 91/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0552 - categorical_accuracy: 0.4627 - val_loss: 0.0799 - val_categorical_accuracy: 0.3837 - lr: 5.0000e-04
# Epoch 92/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0552 - categorical_accuracy: 0.4634 - val_loss: 0.0759 - val_categorical_accuracy: 0.3895 - lr: 5.0000e-04
# Epoch 93/300
# 36/36 [==============================] - 13s 352ms/step - loss: 0.0544 - categorical_accuracy: 0.4766 - val_loss: 0.0798 - val_categorical_accuracy: 0.3943 - lr: 5.0000e-04
# Epoch 94/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0547 - categorical_accuracy: 0.4646 - val_loss: 0.0747 - val_categorical_accuracy: 0.3929 - lr: 5.0000e-04
# Epoch 95/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0541 - categorical_accuracy: 0.4758 - val_loss: 0.0767 - val_categorical_accuracy: 0.4021 - lr: 5.0000e-04
# Epoch 96/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0544 - categorical_accuracy: 0.4738 - val_loss: 0.0720 - val_categorical_accuracy: 0.4077 - lr: 5.0000e-04
# Epoch 97/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0537 - categorical_accuracy: 0.4812 - val_loss: 0.0783 - val_categorical_accuracy: 0.3985 - lr: 5.0000e-04
# Epoch 98/300
# 36/36 [==============================] - 13s 353ms/step - loss: 0.0540 - categorical_accuracy: 0.4782 - val_loss: 0.0718 - val_categorical_accuracy: 0.4078 - lr: 5.0000e-04
# Epoch 99/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0530 - categorical_accuracy: 0.4898 - val_loss: 0.0766 - val_categorical_accuracy: 0.4026 - lr: 5.0000e-04
# Epoch 100/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0535 - categorical_accuracy: 0.4918 - val_loss: 0.0714 - val_categorical_accuracy: 0.4115 - lr: 5.0000e-04
# Epoch 101/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0523 - categorical_accuracy: 0.5140 - val_loss: 0.0765 - val_categorical_accuracy: 0.3947 - lr: 5.0000e-04
# Epoch 102/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0524 - categorical_accuracy: 0.5029 - val_loss: 0.0764 - val_categorical_accuracy: 0.4014 - lr: 5.0000e-04
# Epoch 103/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0522 - categorical_accuracy: 0.5032 - val_loss: 0.0794 - val_categorical_accuracy: 0.3918 - lr: 5.0000e-04
# Epoch 104/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0532 - categorical_accuracy: 0.4891 - val_loss: 0.0748 - val_categorical_accuracy: 0.3968 - lr: 5.0000e-04
# Epoch 105/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0522 - categorical_accuracy: 0.5024 - val_loss: 0.0749 - val_categorical_accuracy: 0.4083 - lr: 5.0000e-04
# Epoch 106/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0523 - categorical_accuracy: 0.5118 - val_loss: 0.0736 - val_categorical_accuracy: 0.4072 - lr: 5.0000e-04
# Epoch 107/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0516 - categorical_accuracy: 0.5152 - val_loss: 0.0793 - val_categorical_accuracy: 0.3761 - lr: 5.0000e-04
# Epoch 108/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0542 - categorical_accuracy: 0.4684 - val_loss: 0.0814 - val_categorical_accuracy: 0.3738 - lr: 5.0000e-04
# Epoch 109/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0551 - categorical_accuracy: 0.4734 - val_loss: 0.0773 - val_categorical_accuracy: 0.3971 - lr: 5.0000e-04
# Epoch 110/300
# 36/36 [==============================] - 13s 350ms/step - loss: 0.0530 - categorical_accuracy: 0.4921 - val_loss: 0.0730 - val_categorical_accuracy: 0.4151 - lr: 5.0000e-04
# Epoch 111/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0517 - categorical_accuracy: 0.5083 - val_loss: 0.0744 - val_categorical_accuracy: 0.4072 - lr: 5.0000e-04
# Epoch 112/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0514 - categorical_accuracy: 0.5129 - val_loss: 0.0735 - val_categorical_accuracy: 0.4106 - lr: 5.0000e-04
# Epoch 113/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0513 - categorical_accuracy: 0.5092 - val_loss: 0.0737 - val_categorical_accuracy: 0.4108 - lr: 5.0000e-04
# Epoch 114/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0509 - categorical_accuracy: 0.5213 - val_loss: 0.0748 - val_categorical_accuracy: 0.4120 - lr: 5.0000e-04
# Epoch 115/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0510 - categorical_accuracy: 0.5169 - val_loss: 0.0742 - val_categorical_accuracy: 0.4152 - lr: 5.0000e-04
# Epoch 116/300
# 36/36 [==============================] - 13s 349ms/step - loss: 0.0507 - categorical_accuracy: 0.5228 - val_loss: 0.0732 - val_categorical_accuracy: 0.4169 - lr: 5.0000e-04
# Epoch 117/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0506 - categorical_accuracy: 0.5263 - val_loss: 0.0729 - val_categorical_accuracy: 0.4193 - lr: 5.0000e-04
# Epoch 118/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0504 - categorical_accuracy: 0.5286 - val_loss: 0.0730 - val_categorical_accuracy: 0.4185 - lr: 5.0000e-04
# Epoch 119/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0502 - categorical_accuracy: 0.5333 - val_loss: 0.0735 - val_categorical_accuracy: 0.4175 - lr: 5.0000e-04
# Epoch 120/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0503 - categorical_accuracy: 0.5307 - val_loss: 0.0747 - val_categorical_accuracy: 0.4127 - lr: 5.0000e-04
# Epoch 121/300
# 36/36 [==============================] - 13s 352ms/step - loss: 0.0504 - categorical_accuracy: 0.5285 - val_loss: 0.0744 - val_categorical_accuracy: 0.4039 - lr: 5.0000e-04
# Epoch 122/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0546 - categorical_accuracy: 0.4571 - val_loss: 0.0775 - val_categorical_accuracy: 0.3838 - lr: 5.0000e-04
# Epoch 123/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0530 - categorical_accuracy: 0.4881 - val_loss: 0.0714 - val_categorical_accuracy: 0.4211 - lr: 5.0000e-04
# Epoch 124/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0513 - categorical_accuracy: 0.5214 - val_loss: 0.0732 - val_categorical_accuracy: 0.4144 - lr: 5.0000e-04
# Epoch 125/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0507 - categorical_accuracy: 0.5223 - val_loss: 0.0727 - val_categorical_accuracy: 0.4222 - lr: 5.0000e-04
# Epoch 126/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0507 - categorical_accuracy: 0.5232 - val_loss: 0.0775 - val_categorical_accuracy: 0.3898 - lr: 5.0000e-04
# Epoch 127/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0513 - categorical_accuracy: 0.5143 - val_loss: 0.0763 - val_categorical_accuracy: 0.4057 - lr: 5.0000e-04
# Epoch 128/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0510 - categorical_accuracy: 0.5209 - val_loss: 0.0724 - val_categorical_accuracy: 0.4141 - lr: 5.0000e-04
# Epoch 129/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0507 - categorical_accuracy: 0.5202 - val_loss: 0.0737 - val_categorical_accuracy: 0.4086 - lr: 5.0000e-04
# Epoch 130/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0504 - categorical_accuracy: 0.5300 - val_loss: 0.0744 - val_categorical_accuracy: 0.4097 - lr: 5.0000e-04
# Epoch 131/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0505 - categorical_accuracy: 0.5297 - val_loss: 0.0738 - val_categorical_accuracy: 0.4158 - lr: 5.0000e-04
# Epoch 132/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0505 - categorical_accuracy: 0.5212 - val_loss: 0.0740 - val_categorical_accuracy: 0.4185 - lr: 5.0000e-04
# Epoch 133/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0504 - categorical_accuracy: 0.5309 - val_loss: 0.0739 - val_categorical_accuracy: 0.4170 - lr: 5.0000e-04
# Epoch 134/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0497 - categorical_accuracy: 0.5373 - val_loss: 0.0762 - val_categorical_accuracy: 0.4022 - lr: 5.0000e-04
# Epoch 135/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0502 - categorical_accuracy: 0.5283 - val_loss: 0.0726 - val_categorical_accuracy: 0.4238 - lr: 5.0000e-04
# Epoch 136/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0498 - categorical_accuracy: 0.5364 - val_loss: 0.0725 - val_categorical_accuracy: 0.4180 - lr: 5.0000e-04
# Epoch 137/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0494 - categorical_accuracy: 0.5368 - val_loss: 0.0728 - val_categorical_accuracy: 0.4209 - lr: 5.0000e-04
# Epoch 138/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0491 - categorical_accuracy: 0.5493 - val_loss: 0.0757 - val_categorical_accuracy: 0.4043 - lr: 5.0000e-04
# Epoch 139/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0503 - categorical_accuracy: 0.5237 - val_loss: 0.0707 - val_categorical_accuracy: 0.4343 - lr: 5.0000e-04
# Epoch 140/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0493 - categorical_accuracy: 0.5459 - val_loss: 0.0706 - val_categorical_accuracy: 0.4291 - lr: 5.0000e-04
# Epoch 141/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0489 - categorical_accuracy: 0.5542 - val_loss: 0.0743 - val_categorical_accuracy: 0.4145 - lr: 5.0000e-04
# Epoch 142/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0489 - categorical_accuracy: 0.5555 - val_loss: 0.0744 - val_categorical_accuracy: 0.4136 - lr: 5.0000e-04
# Epoch 143/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0490 - categorical_accuracy: 0.5488 - val_loss: 0.0761 - val_categorical_accuracy: 0.4108 - lr: 5.0000e-04
# Epoch 144/300
# 36/36 [==============================] - 13s 352ms/step - loss: 0.0495 - categorical_accuracy: 0.5381 - val_loss: 0.0737 - val_categorical_accuracy: 0.4219 - lr: 5.0000e-04
# Epoch 145/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.0493 - categorical_accuracy: 0.5412 - val_loss: 0.0717 - val_categorical_accuracy: 0.4271 - lr: 5.0000e-04
# Epoch 146/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0488 - categorical_accuracy: 0.5534 - val_loss: 0.0717 - val_categorical_accuracy: 0.4267 - lr: 5.0000e-04
# Epoch 147/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0487 - categorical_accuracy: 0.5554 - val_loss: 0.0715 - val_categorical_accuracy: 0.4289 - lr: 5.0000e-04
# Epoch 148/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0482 - categorical_accuracy: 0.5634 - val_loss: 0.0730 - val_categorical_accuracy: 0.4197 - lr: 5.0000e-04
# Epoch 149/300
# 36/36 [==============================] - 13s 352ms/step - loss: 0.0484 - categorical_accuracy: 0.5630 - val_loss: 0.0740 - val_categorical_accuracy: 0.4195 - lr: 5.0000e-04
# Epoch 150/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0487 - categorical_accuracy: 0.5509 - val_loss: 0.0742 - val_categorical_accuracy: 0.4207 - lr: 5.0000e-04
# Epoch 151/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0484 - categorical_accuracy: 0.5583 - val_loss: 0.0736 - val_categorical_accuracy: 0.4240 - lr: 5.0000e-04
# Epoch 152/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0486 - categorical_accuracy: 0.5545 - val_loss: 0.0708 - val_categorical_accuracy: 0.4330 - lr: 5.0000e-04
# Epoch 153/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0481 - categorical_accuracy: 0.5644 - val_loss: 0.0712 - val_categorical_accuracy: 0.4305 - lr: 5.0000e-04
# Epoch 154/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0481 - categorical_accuracy: 0.5633 - val_loss: 0.0717 - val_categorical_accuracy: 0.4257 - lr: 5.0000e-04
# Epoch 155/300
# 36/36 [==============================] - 13s 353ms/step - loss: 0.0478 - categorical_accuracy: 0.5675 - val_loss: 0.0750 - val_categorical_accuracy: 0.4105 - lr: 5.0000e-04
# Epoch 156/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0483 - categorical_accuracy: 0.5580 - val_loss: 0.0750 - val_categorical_accuracy: 0.4069 - lr: 5.0000e-04
# Epoch 157/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0494 - categorical_accuracy: 0.5380 - val_loss: 0.0712 - val_categorical_accuracy: 0.4356 - lr: 5.0000e-04
# Epoch 158/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0482 - categorical_accuracy: 0.5620 - val_loss: 0.0712 - val_categorical_accuracy: 0.4285 - lr: 5.0000e-04
# Epoch 159/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0481 - categorical_accuracy: 0.5627 - val_loss: 0.0714 - val_categorical_accuracy: 0.4319 - lr: 5.0000e-04
# Epoch 160/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0477 - categorical_accuracy: 0.5732 - val_loss: 0.0747 - val_categorical_accuracy: 0.4161 - lr: 5.0000e-04
# Epoch 161/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0482 - categorical_accuracy: 0.5602 - val_loss: 0.0730 - val_categorical_accuracy: 0.4183 - lr: 5.0000e-04
# Epoch 162/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0482 - categorical_accuracy: 0.5608 - val_loss: 0.0722 - val_categorical_accuracy: 0.4281 - lr: 5.0000e-04
# Epoch 163/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0480 - categorical_accuracy: 0.5666 - val_loss: 0.0716 - val_categorical_accuracy: 0.4281 - lr: 5.0000e-04
# Epoch 164/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0478 - categorical_accuracy: 0.5685 - val_loss: 0.0738 - val_categorical_accuracy: 0.4203 - lr: 5.0000e-04
# Epoch 165/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0479 - categorical_accuracy: 0.5651 - val_loss: 0.0732 - val_categorical_accuracy: 0.4217 - lr: 5.0000e-04
# Epoch 166/300
# 36/36 [==============================] - 13s 352ms/step - loss: 0.0479 - categorical_accuracy: 0.5702 - val_loss: 0.0711 - val_categorical_accuracy: 0.4333 - lr: 5.0000e-04
# Epoch 167/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0476 - categorical_accuracy: 0.5720 - val_loss: 0.0709 - val_categorical_accuracy: 0.4296 - lr: 5.0000e-04
# Epoch 168/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0476 - categorical_accuracy: 0.5714 - val_loss: 0.0719 - val_categorical_accuracy: 0.4253 - lr: 5.0000e-04
# Epoch 169/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0471 - categorical_accuracy: 0.5822 - val_loss: 0.0735 - val_categorical_accuracy: 0.4171 - lr: 5.0000e-04
# Epoch 170/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0480 - categorical_accuracy: 0.5657 - val_loss: 0.0719 - val_categorical_accuracy: 0.4284 - lr: 5.0000e-04
# Epoch 171/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0472 - categorical_accuracy: 0.5778 - val_loss: 0.0727 - val_categorical_accuracy: 0.4227 - lr: 5.0000e-04
# Epoch 172/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0474 - categorical_accuracy: 0.5775 - val_loss: 0.0718 - val_categorical_accuracy: 0.4260 - lr: 5.0000e-04
# Epoch 173/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0473 - categorical_accuracy: 0.5777 - val_loss: 0.0715 - val_categorical_accuracy: 0.4237 - lr: 5.0000e-04
# Epoch 174/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0478 - categorical_accuracy: 0.5647 - val_loss: 0.0709 - val_categorical_accuracy: 0.4308 - lr: 5.0000e-04
# Epoch 175/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0469 - categorical_accuracy: 0.5894 - val_loss: 0.0727 - val_categorical_accuracy: 0.4151 - lr: 5.0000e-04
# Epoch 176/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0475 - categorical_accuracy: 0.5719 - val_loss: 0.0752 - val_categorical_accuracy: 0.3964 - lr: 5.0000e-04
# Epoch 177/300
# 36/36 [==============================] - 13s 354ms/step - loss: 0.0479 - categorical_accuracy: 0.5640 - val_loss: 0.0745 - val_categorical_accuracy: 0.4130 - lr: 5.0000e-04
# Epoch 178/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0474 - categorical_accuracy: 0.5754 - val_loss: 0.0702 - val_categorical_accuracy: 0.4325 - lr: 5.0000e-04
# Epoch 179/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0471 - categorical_accuracy: 0.5781 - val_loss: 0.0734 - val_categorical_accuracy: 0.4019 - lr: 5.0000e-04
# Epoch 180/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0471 - categorical_accuracy: 0.5813 - val_loss: 0.0717 - val_categorical_accuracy: 0.4252 - lr: 5.0000e-04
# Epoch 181/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0468 - categorical_accuracy: 0.5860 - val_loss: 0.0721 - val_categorical_accuracy: 0.4128 - lr: 5.0000e-04
# Epoch 182/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0468 - categorical_accuracy: 0.5832 - val_loss: 0.0725 - val_categorical_accuracy: 0.4149 - lr: 5.0000e-04
# Epoch 183/300
# 36/36 [==============================] - 13s 352ms/step - loss: 0.0467 - categorical_accuracy: 0.5888 - val_loss: 0.0728 - val_categorical_accuracy: 0.4108 - lr: 5.0000e-04
# Epoch 184/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0467 - categorical_accuracy: 0.5888 - val_loss: 0.0730 - val_categorical_accuracy: 0.4116 - lr: 5.0000e-04
# Epoch 185/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0467 - categorical_accuracy: 0.5863 - val_loss: 0.0721 - val_categorical_accuracy: 0.4136 - lr: 5.0000e-04
# Epoch 186/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0466 - categorical_accuracy: 0.5857 - val_loss: 0.0730 - val_categorical_accuracy: 0.4097 - lr: 5.0000e-04
# Epoch 187/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0468 - categorical_accuracy: 0.5840 - val_loss: 0.0722 - val_categorical_accuracy: 0.4156 - lr: 5.0000e-04
# Epoch 188/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0467 - categorical_accuracy: 0.5837 - val_loss: 0.0720 - val_categorical_accuracy: 0.4147 - lr: 5.0000e-04
# Epoch 189/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0466 - categorical_accuracy: 0.5846 - val_loss: 0.0720 - val_categorical_accuracy: 0.4212 - lr: 5.0000e-04
# Epoch 190/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0464 - categorical_accuracy: 0.5864 - val_loss: 0.0737 - val_categorical_accuracy: 0.4128 - lr: 5.0000e-04
# Epoch 191/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0467 - categorical_accuracy: 0.5847 - val_loss: 0.0731 - val_categorical_accuracy: 0.4189 - lr: 5.0000e-04
# Epoch 192/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0470 - categorical_accuracy: 0.5801 - val_loss: 0.0705 - val_categorical_accuracy: 0.4322 - lr: 5.0000e-04
# Epoch 193/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0465 - categorical_accuracy: 0.5879 - val_loss: 0.0697 - val_categorical_accuracy: 0.4353 - lr: 5.0000e-04
# Epoch 194/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0462 - categorical_accuracy: 0.5949 - val_loss: 0.0711 - val_categorical_accuracy: 0.4266 - lr: 5.0000e-04
# Epoch 195/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0461 - categorical_accuracy: 0.5985 - val_loss: 0.0745 - val_categorical_accuracy: 0.4147 - lr: 5.0000e-04
# Epoch 196/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0466 - categorical_accuracy: 0.5861 - val_loss: 0.0752 - val_categorical_accuracy: 0.4208 - lr: 5.0000e-04
# Epoch 197/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0472 - categorical_accuracy: 0.5765 - val_loss: 0.0697 - val_categorical_accuracy: 0.4381 - lr: 5.0000e-04
# Epoch 198/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0484 - categorical_accuracy: 0.5483 - val_loss: 0.0739 - val_categorical_accuracy: 0.4194 - lr: 5.0000e-04
# Epoch 199/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0477 - categorical_accuracy: 0.5719 - val_loss: 0.0727 - val_categorical_accuracy: 0.4135 - lr: 5.0000e-04
# Epoch 200/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0477 - categorical_accuracy: 0.5676 - val_loss: 0.0738 - val_categorical_accuracy: 0.4204 - lr: 5.0000e-04
# Epoch 201/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0466 - categorical_accuracy: 0.5889 - val_loss: 0.0745 - val_categorical_accuracy: 0.4040 - lr: 5.0000e-04
# Epoch 202/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.0478 - categorical_accuracy: 0.5592 - val_loss: 0.0746 - val_categorical_accuracy: 0.4265 - lr: 5.0000e-04
# Epoch 203/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.0474 - categorical_accuracy: 0.5770 - val_loss: 0.0717 - val_categorical_accuracy: 0.4251 - lr: 5.0000e-04
# Epoch 204/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0475 - categorical_accuracy: 0.5757 - val_loss: 0.0704 - val_categorical_accuracy: 0.4385 - lr: 5.0000e-04
# Epoch 205/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0463 - categorical_accuracy: 0.5905 - val_loss: 0.0723 - val_categorical_accuracy: 0.4266 - lr: 5.0000e-04
# Epoch 206/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.0464 - categorical_accuracy: 0.5897 - val_loss: 0.0736 - val_categorical_accuracy: 0.4238 - lr: 5.0000e-04
# Epoch 207/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0464 - categorical_accuracy: 0.5900 - val_loss: 0.0716 - val_categorical_accuracy: 0.4382 - lr: 5.0000e-04
# Epoch 208/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0463 - categorical_accuracy: 0.5912 - val_loss: 0.0696 - val_categorical_accuracy: 0.4506 - lr: 5.0000e-04
# Epoch 209/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0455 - categorical_accuracy: 0.6048 - val_loss: 0.0717 - val_categorical_accuracy: 0.4314 - lr: 5.0000e-04
# Epoch 210/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0458 - categorical_accuracy: 0.6005 - val_loss: 0.0732 - val_categorical_accuracy: 0.4176 - lr: 5.0000e-04
# Epoch 211/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0459 - categorical_accuracy: 0.5971 - val_loss: 0.0712 - val_categorical_accuracy: 0.4368 - lr: 5.0000e-04
# Epoch 212/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.0459 - categorical_accuracy: 0.5968 - val_loss: 0.0710 - val_categorical_accuracy: 0.4397 - lr: 5.0000e-04
# Epoch 213/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0452 - categorical_accuracy: 0.6088 - val_loss: 0.0719 - val_categorical_accuracy: 0.4241 - lr: 5.0000e-04
# Epoch 214/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.0456 - categorical_accuracy: 0.6026 - val_loss: 0.0728 - val_categorical_accuracy: 0.4245 - lr: 5.0000e-04
# Epoch 215/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0458 - categorical_accuracy: 0.6026 - val_loss: 0.0710 - val_categorical_accuracy: 0.4373 - lr: 5.0000e-04
# Epoch 216/300
# 36/36 [==============================] - 13s 350ms/step - loss: 0.0457 - categorical_accuracy: 0.6006 - val_loss: 0.0698 - val_categorical_accuracy: 0.4472 - lr: 5.0000e-04
# Epoch 217/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0450 - categorical_accuracy: 0.6120 - val_loss: 0.0713 - val_categorical_accuracy: 0.4320 - lr: 5.0000e-04
# Epoch 218/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0452 - categorical_accuracy: 0.6093 - val_loss: 0.0730 - val_categorical_accuracy: 0.4151 - lr: 5.0000e-04
# Epoch 219/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0454 - categorical_accuracy: 0.6060 - val_loss: 0.0719 - val_categorical_accuracy: 0.4286 - lr: 5.0000e-04
# Epoch 220/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0461 - categorical_accuracy: 0.5967 - val_loss: 0.0723 - val_categorical_accuracy: 0.4240 - lr: 5.0000e-04
# Epoch 221/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0467 - categorical_accuracy: 0.5868 - val_loss: 0.0701 - val_categorical_accuracy: 0.4348 - lr: 5.0000e-04
# Epoch 222/300
# 36/36 [==============================] - 13s 352ms/step - loss: 0.0464 - categorical_accuracy: 0.5898 - val_loss: 0.0706 - val_categorical_accuracy: 0.4261 - lr: 5.0000e-04
# Epoch 223/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0460 - categorical_accuracy: 0.5970 - val_loss: 0.0738 - val_categorical_accuracy: 0.4079 - lr: 5.0000e-04
# Epoch 224/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0458 - categorical_accuracy: 0.6030 - val_loss: 0.0745 - val_categorical_accuracy: 0.4112 - lr: 5.0000e-04
# Epoch 225/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0467 - categorical_accuracy: 0.5845 - val_loss: 0.0705 - val_categorical_accuracy: 0.4272 - lr: 5.0000e-04
# Epoch 226/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0455 - categorical_accuracy: 0.6024 - val_loss: 0.0698 - val_categorical_accuracy: 0.4333 - lr: 5.0000e-04
# Epoch 227/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0446 - categorical_accuracy: 0.6207 - val_loss: 0.0741 - val_categorical_accuracy: 0.3997 - lr: 5.0000e-04
# Epoch 228/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0456 - categorical_accuracy: 0.6042 - val_loss: 0.0720 - val_categorical_accuracy: 0.4117 - lr: 5.0000e-04
# Epoch 229/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0453 - categorical_accuracy: 0.6101 - val_loss: 0.0712 - val_categorical_accuracy: 0.4192 - lr: 5.0000e-04
# Epoch 230/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0452 - categorical_accuracy: 0.6081 - val_loss: 0.0727 - val_categorical_accuracy: 0.3933 - lr: 5.0000e-04
# Epoch 231/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.0448 - categorical_accuracy: 0.6196 - val_loss: 0.0740 - val_categorical_accuracy: 0.3986 - lr: 5.0000e-04
# Epoch 232/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0456 - categorical_accuracy: 0.6025 - val_loss: 0.0764 - val_categorical_accuracy: 0.3856 - lr: 5.0000e-04
# Epoch 233/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0465 - categorical_accuracy: 0.5909 - val_loss: 0.0705 - val_categorical_accuracy: 0.4270 - lr: 5.0000e-04
# Epoch 234/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0457 - categorical_accuracy: 0.5977 - val_loss: 0.0725 - val_categorical_accuracy: 0.4038 - lr: 5.0000e-04
# Epoch 235/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0453 - categorical_accuracy: 0.6084 - val_loss: 0.0729 - val_categorical_accuracy: 0.4137 - lr: 5.0000e-04
# Epoch 236/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0450 - categorical_accuracy: 0.6110 - val_loss: 0.0728 - val_categorical_accuracy: 0.4041 - lr: 5.0000e-04
# Epoch 237/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0456 - categorical_accuracy: 0.6027 - val_loss: 0.0715 - val_categorical_accuracy: 0.4197 - lr: 5.0000e-04
# Epoch 238/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0450 - categorical_accuracy: 0.6072 - val_loss: 0.0724 - val_categorical_accuracy: 0.4125 - lr: 5.0000e-04
# Epoch 239/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0452 - categorical_accuracy: 0.6089 - val_loss: 0.0730 - val_categorical_accuracy: 0.4128 - lr: 5.0000e-04
# Epoch 240/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0452 - categorical_accuracy: 0.6056 - val_loss: 0.0741 - val_categorical_accuracy: 0.4140 - lr: 5.0000e-04
# Epoch 241/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0453 - categorical_accuracy: 0.6071 - val_loss: 0.0692 - val_categorical_accuracy: 0.4406 - lr: 5.0000e-04
# Epoch 242/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.0450 - categorical_accuracy: 0.6127 - val_loss: 0.0691 - val_categorical_accuracy: 0.4373 - lr: 5.0000e-04
# Epoch 243/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.0443 - categorical_accuracy: 0.6215 - val_loss: 0.0714 - val_categorical_accuracy: 0.4141 - lr: 5.0000e-04
# Epoch 244/300
# 36/36 [==============================] - 13s 352ms/step - loss: 0.0444 - categorical_accuracy: 0.6239 - val_loss: 0.0750 - val_categorical_accuracy: 0.4062 - lr: 5.0000e-04
# Epoch 245/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0450 - categorical_accuracy: 0.6111 - val_loss: 0.0699 - val_categorical_accuracy: 0.4381 - lr: 5.0000e-04
# Epoch 246/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.0445 - categorical_accuracy: 0.6173 - val_loss: 0.0714 - val_categorical_accuracy: 0.4213 - lr: 5.0000e-04
# Epoch 247/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0441 - categorical_accuracy: 0.6237 - val_loss: 0.0712 - val_categorical_accuracy: 0.4227 - lr: 5.0000e-04
# Epoch 248/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0440 - categorical_accuracy: 0.6284 - val_loss: 0.0730 - val_categorical_accuracy: 0.4101 - lr: 5.0000e-04
# Epoch 249/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.0444 - categorical_accuracy: 0.6195 - val_loss: 0.0725 - val_categorical_accuracy: 0.4288 - lr: 5.0000e-04
# Epoch 250/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0445 - categorical_accuracy: 0.6209 - val_loss: 0.0684 - val_categorical_accuracy: 0.4423 - lr: 5.0000e-04
# Epoch 251/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0441 - categorical_accuracy: 0.6242 - val_loss: 0.0684 - val_categorical_accuracy: 0.4433 - lr: 5.0000e-04
# Epoch 252/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0435 - categorical_accuracy: 0.6342 - val_loss: 0.0715 - val_categorical_accuracy: 0.4227 - lr: 5.0000e-04
# Epoch 253/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0437 - categorical_accuracy: 0.6348 - val_loss: 0.0758 - val_categorical_accuracy: 0.3986 - lr: 5.0000e-04
# Epoch 254/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0450 - categorical_accuracy: 0.6120 - val_loss: 0.0700 - val_categorical_accuracy: 0.4372 - lr: 5.0000e-04
# Epoch 255/300
# 36/36 [==============================] - 13s 352ms/step - loss: 0.0445 - categorical_accuracy: 0.6206 - val_loss: 0.0726 - val_categorical_accuracy: 0.4199 - lr: 5.0000e-04
# Epoch 256/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.0447 - categorical_accuracy: 0.6172 - val_loss: 0.0723 - val_categorical_accuracy: 0.4223 - lr: 5.0000e-04
# Epoch 257/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.0444 - categorical_accuracy: 0.6238 - val_loss: 0.0751 - val_categorical_accuracy: 0.3978 - lr: 5.0000e-04
# Epoch 258/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0461 - categorical_accuracy: 0.5895 - val_loss: 0.0769 - val_categorical_accuracy: 0.3944 - lr: 5.0000e-04
# Epoch 259/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0458 - categorical_accuracy: 0.6024 - val_loss: 0.0719 - val_categorical_accuracy: 0.4174 - lr: 5.0000e-04
# Epoch 260/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0461 - categorical_accuracy: 0.5837 - val_loss: 0.0742 - val_categorical_accuracy: 0.4217 - lr: 5.0000e-04
# Epoch 261/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0453 - categorical_accuracy: 0.6144 - val_loss: 0.0714 - val_categorical_accuracy: 0.4028 - lr: 5.0000e-04
# Epoch 262/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0444 - categorical_accuracy: 0.6215 - val_loss: 0.0757 - val_categorical_accuracy: 0.3885 - lr: 5.0000e-04
# Epoch 263/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0456 - categorical_accuracy: 0.6003 - val_loss: 0.0707 - val_categorical_accuracy: 0.4242 - lr: 5.0000e-04
# Epoch 264/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0440 - categorical_accuracy: 0.6278 - val_loss: 0.0736 - val_categorical_accuracy: 0.3980 - lr: 5.0000e-04
# Epoch 265/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0447 - categorical_accuracy: 0.6174 - val_loss: 0.0698 - val_categorical_accuracy: 0.4267 - lr: 5.0000e-04
# Epoch 266/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0432 - categorical_accuracy: 0.6406 - val_loss: 0.0751 - val_categorical_accuracy: 0.3962 - lr: 5.0000e-04
# Epoch 267/300
# 36/36 [==============================] - 13s 352ms/step - loss: 0.0445 - categorical_accuracy: 0.6212 - val_loss: 0.0712 - val_categorical_accuracy: 0.4132 - lr: 5.0000e-04
# Epoch 268/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.0436 - categorical_accuracy: 0.6336 - val_loss: 0.0712 - val_categorical_accuracy: 0.4065 - lr: 5.0000e-04
# Epoch 269/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0439 - categorical_accuracy: 0.6297 - val_loss: 0.0734 - val_categorical_accuracy: 0.3968 - lr: 5.0000e-04
# Epoch 270/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.0437 - categorical_accuracy: 0.6335 - val_loss: 0.0749 - val_categorical_accuracy: 0.3881 - lr: 5.0000e-04
# Epoch 271/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0442 - categorical_accuracy: 0.6239 - val_loss: 0.0727 - val_categorical_accuracy: 0.4074 - lr: 5.0000e-04
# Epoch 272/300
# 36/36 [==============================] - 13s 351ms/step - loss: 0.0439 - categorical_accuracy: 0.6268 - val_loss: 0.0736 - val_categorical_accuracy: 0.3927 - lr: 5.0000e-04
# Epoch 273/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.0440 - categorical_accuracy: 0.6265 - val_loss: 0.0727 - val_categorical_accuracy: 0.4101 - lr: 5.0000e-04
# Epoch 274/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0436 - categorical_accuracy: 0.6301 - val_loss: 0.0722 - val_categorical_accuracy: 0.4055 - lr: 5.0000e-04
# Epoch 275/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0442 - categorical_accuracy: 0.6214 - val_loss: 0.0709 - val_categorical_accuracy: 0.4202 - lr: 5.0000e-04
# Epoch 276/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0435 - categorical_accuracy: 0.6329 - val_loss: 0.0718 - val_categorical_accuracy: 0.4152 - lr: 5.0000e-04
# Epoch 277/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0434 - categorical_accuracy: 0.6349 - val_loss: 0.0719 - val_categorical_accuracy: 0.4142 - lr: 5.0000e-04
# Epoch 278/300
# 36/36 [==============================] - 13s 350ms/step - loss: 0.0433 - categorical_accuracy: 0.6357 - val_loss: 0.0701 - val_categorical_accuracy: 0.4209 - lr: 5.0000e-04
# Epoch 279/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0424 - categorical_accuracy: 0.6479 - val_loss: 0.0746 - val_categorical_accuracy: 0.4053 - lr: 5.0000e-04
# Epoch 280/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0438 - categorical_accuracy: 0.6328 - val_loss: 0.0717 - val_categorical_accuracy: 0.4103 - lr: 5.0000e-04
# Epoch 281/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0430 - categorical_accuracy: 0.6427 - val_loss: 0.0739 - val_categorical_accuracy: 0.4063 - lr: 5.0000e-04
# Epoch 282/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0433 - categorical_accuracy: 0.6352 - val_loss: 0.0708 - val_categorical_accuracy: 0.4181 - lr: 5.0000e-04
# Epoch 283/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0427 - categorical_accuracy: 0.6475 - val_loss: 0.0736 - val_categorical_accuracy: 0.4111 - lr: 5.0000e-04
# Epoch 284/300
# 36/36 [==============================] - 13s 349ms/step - loss: 0.0431 - categorical_accuracy: 0.6402 - val_loss: 0.0725 - val_categorical_accuracy: 0.4058 - lr: 5.0000e-04
# Epoch 285/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0430 - categorical_accuracy: 0.6406 - val_loss: 0.0746 - val_categorical_accuracy: 0.3990 - lr: 5.0000e-04
# Epoch 286/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0435 - categorical_accuracy: 0.6337 - val_loss: 0.0705 - val_categorical_accuracy: 0.4160 - lr: 5.0000e-04
# Epoch 287/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0425 - categorical_accuracy: 0.6483 - val_loss: 0.0749 - val_categorical_accuracy: 0.4001 - lr: 5.0000e-04
# Epoch 288/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0430 - categorical_accuracy: 0.6420 - val_loss: 0.0718 - val_categorical_accuracy: 0.4135 - lr: 5.0000e-04
# Epoch 289/300
# 36/36 [==============================] - 13s 350ms/step - loss: 0.0428 - categorical_accuracy: 0.6472 - val_loss: 0.0725 - val_categorical_accuracy: 0.4057 - lr: 5.0000e-04
# Epoch 290/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0434 - categorical_accuracy: 0.6358 - val_loss: 0.0703 - val_categorical_accuracy: 0.4266 - lr: 5.0000e-04
# Epoch 291/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0419 - categorical_accuracy: 0.6581 - val_loss: 0.0751 - val_categorical_accuracy: 0.3881 - lr: 5.0000e-04
# Epoch 292/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0430 - categorical_accuracy: 0.6475 - val_loss: 0.0719 - val_categorical_accuracy: 0.4199 - lr: 5.0000e-04
# Epoch 293/300
# 36/36 [==============================] - 13s 341ms/step - loss: 0.0427 - categorical_accuracy: 0.6459 - val_loss: 0.0707 - val_categorical_accuracy: 0.4279 - lr: 5.0000e-04
# Epoch 294/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0427 - categorical_accuracy: 0.6492 - val_loss: 0.0717 - val_categorical_accuracy: 0.4199 - lr: 5.0000e-04
# Epoch 295/300
# 36/36 [==============================] - 13s 352ms/step - loss: 0.0421 - categorical_accuracy: 0.6566 - val_loss: 0.0741 - val_categorical_accuracy: 0.3978 - lr: 5.0000e-04
# Epoch 296/300
# 36/36 [==============================] - 13s 344ms/step - loss: 0.0427 - categorical_accuracy: 0.6515 - val_loss: 0.0739 - val_categorical_accuracy: 0.3934 - lr: 5.0000e-04
# Epoch 297/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0430 - categorical_accuracy: 0.6403 - val_loss: 0.0747 - val_categorical_accuracy: 0.3915 - lr: 5.0000e-04
# Epoch 298/300
# 36/36 [==============================] - 13s 342ms/step - loss: 0.0433 - categorical_accuracy: 0.6390 - val_loss: 0.0733 - val_categorical_accuracy: 0.3967 - lr: 5.0000e-04
# Epoch 299/300
# 36/36 [==============================] - 13s 343ms/step - loss: 0.0433 - categorical_accuracy: 0.6311 - val_loss: 0.0732 - val_categorical_accuracy: 0.4007 - lr: 5.0000e-04
# Epoch 300/300
# 36/36 [==============================] - 13s 345ms/step - loss: 0.0428 - categorical_accuracy: 0.6502 - val_loss: 0.0726 - val_categorical_accuracy: 0.3972 - lr: 5.0000e-04

# %%
cosme_model.save_weights(model_weights_dir)

# %%
cosme_model.evaluate(valid_dataset)
# Out:
# 39/39 [==============================] - 1s 9ms/step - loss: 0.0726 - categorical_accuracy: 0.3972
# [0.0726083368062973, 0.39719802141189575]

# %%
cosme_model.evaluate(train_dataset)
# Out:
# 36/36 [==============================] - 4s 113ms/step - loss: 0.0722 - categorical_accuracy: 0.4098
# [0.07215527445077896, 0.4098244607448578]

# %%
cosme_model.training = False

# %%
cosme_model.evaluate(valid_dataset)
# Out:
# 39/39 [==============================] - 1s 9ms/step - loss: 0.0726 - categorical_accuracy: 0.3972
# [0.0726083368062973, 0.39719802141189575]

# %%
cosme_model.evaluate(train_dataset)
# Out:
# 36/36 [==============================] - 4s 114ms/step - loss: 0.0722 - categorical_accuracy: 0.4098
# [0.07215527445077896, 0.4098244607448578]

# %%
# cosme_model.predict(valid_dataset).argmax(1)
